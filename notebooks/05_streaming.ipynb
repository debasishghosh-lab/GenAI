# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq

llm=ChatGroq(model="openai/gpt-oss-20b",streaming=True)

# %%
response=llm.stream("explain me gen ai in very details ..")

for chunck in response:
    print(chunck.content,end="")
# Out:
# ## Generative AI – A Deep Dive
#
# > **Generative AI** (Gen‑AI) refers to a class of machine‑learning models that *create* new data that mimics the distribution of a training set.
# > Instead of merely *classifying* or *predicting* an outcome, generative models produce **synthetic samples**: text, images, audio, video, code, 3‑D shapes, even entire conversations.
#
# Below is a comprehensive guide that covers the **why, how, what, and where** of generative AI.
#
# ---
#
# ### 1. Core Concepts
#
# | Concept | What It Is | Why It Matters |
# |---------|------------|----------------|
# | **Generative vs. Discriminative** | Discriminative models learn *P(y|x)* (e.g., classify spam). Generative models learn *P(x, y)* or *P(x)* (e.g., generate new emails). | Generative models can *sample* new data, enabling creativity, simulation, and data augmentation. |
# | **Latent Space** | A compressed, often continuous, representation of data. | Enables interpolation, style transfer, and efficient sampling. |
# | **Autoregressive Models** | Generate data token‑by‑token, conditioning on previously generated tokens. | Guarantees coherence and controllability; used in GPT, PixelCNN. |
# | **Diffusion Models** | Iteratively denoise a random noise vector to produce realistic samples. | State‑of‑the‑art for image/video generation; highly controllable. |
# | **Variational Auto‑Encoders (VAEs)** | Encode data to a latent distribution, then decode. | Provide a principled probabilistic framework; good for sampling and representation learning. |
# | **Generative Adversarial Networks (GANs)** | Two networks (generator & discriminator) compete. | Produce sharp, high‑resolution images; widely used in art & fashion. |
# | **Transformers** | Self‑attention architecture that scales to billions of parameters. | The backbone of modern Gen‑AI (text, multimodal, code). |
#
# ---
#
# ### 2. Evolution Timeline
#
# | Year | Milestone | Impact |
# |------|-----------|--------|
# | **1997** | *Bengio et al.* introduce VAEs | First deep generative model with a probabilistic objective. |
# | **2014** | *Goodfellow et al.* publish GANs | Sparked a flood of research on adversarial training. |
# | **2015** | *Radford et al.* publish DCGAN | Showed GANs can generate realistic images. |
# | **2017** | *Vaswani et al.* introduce Transformers | Revolutionized NLP and later generative modeling. |
# | **2018** | *OpenAI GPT* (1) | First large‑scale autoregressive language model. |
# | **2019** | *DALL‑E* (image‑text) | First text‑to‑image generative model. |
# | **2020** | *Stable Diffusion* & *DALL‑E 2* | Diffusion models outperform GANs on image quality. |
# | **2021** | *ChatGPT* (GPT‑3.5) | Demonstrated conversational Gen‑AI. |
# | **2022** | *PaLM, LLaMA, Gemini* | Scaling laws clarified model performance vs. compute. |
# | **2023** | *OpenAI GPT‑4*, *Claude 3*, *DeepMind Gemini* | Multi‑modal, higher‑accuracy generative models. |
# | **2024** | *OpenAI Gemini Pro*, *Anthropic Claude 3.5*, *Stability AI Stable Diffusion 3* | Generative AI is mainstream in business, creative industries, and research. |
#
# ---
#
# ### 3. Architecture Deep‑Dive
#
# #### 3.1 Transformers (Autoregressive)
#
# - **Self‑Attention**: Computes pairwise interactions between tokens; allows long‑range context.
# - **Positional Encoding**: Adds order information (sinusoidal or learned).
# - **Layer Normalization + Residuals**: Stabilizes training.
# - **Feed‑Forward Network (FFN)**: 2‑layer MLP per token.
# - **Scalability**: Parameter count → 100M–100B+, compute → TFLOPs.
#
# ##### Training Objective
# - **Cross‑Entropy Loss** over next‑token prediction.
# - **Masked Language Modeling** (BERT) is *bidirectional* but not autoregressive; still used for pre‑training.
#
# #### 3.2 Diffusion Models
#
# - **Forward Process**: Add Gaussian noise over *T* steps until data is pure noise.
# - **Reverse Process**: Train a neural net to predict noise at each step (or denoise).
# - **Sampling**: Start from noise, iteratively refine → high‑quality images.
# - **Score‑Matching**: Equivalent to training a denoising auto‑encoder.
#
# ##### Variants
# - **DDPM** (Denoising Diffusion Probabilistic Models)
# - **DDIM** (Denoising Diffusion Implicit Models) – faster sampling.
# - **Stable Diffusion** – latent diffusion in compressed space (e.g., 512×512 → 64×64 latent).
#
# #### 3.3 VAEs
#
# - **Encoder**: Maps input *x* to *μ, σ* → latent *z*.
# - **Decoder**: Reconstructs *x̂* from *z*.
# - **Loss**: Reconstruction + KL divergence (regularizer).
# - **Pros**: Probabilistic, easy to sample; **Cons**: Blurry outputs.
#
# #### 3.4 GANs
#
# - **Generator (G)**: Maps random noise *z* to data *x̂*.
# - **Discriminator (D)**: Distinguishes real *x* from *x̂*.
# - **Adversarial Loss**: Minimax game; *G* tries to fool *D*.
# - **Variants**: StyleGAN (style‑based generator), BigGAN (large‑scale), CycleGAN (image‑to‑image).
#
# ---
#
# ### 4. Training Pipeline
#
# | Step | Detail | Typical Tools |
# |------|--------|--------------|
# | **Data Collection** | Massive corpora (text: books, web; images: ImageNet, LAION). | Scrapers, public datasets, proprietary corpora. |
# | **Pre‑processing** | Tokenization (BPE, SentencePiece), cleaning, deduplication. | Hugging Face tokenizers, spaCy. |
# | **Tokenization** | Subword units to balance vocabulary size vs. granularity. | GPT‑2 Byte‑Pair Encoding, SentencePiece. |
# | **Model Initialization** | Random or pre‑trained weights. | PyTorch, TensorFlow. |
# | **Training Loop** | Forward pass → loss → backward → optimizer step. | AdamW, LAMB, RAdam. |
# | **Scaling Laws** | Model size × dataset size × compute → performance. | Empirical formulas (Kaplan et al.). |
# | **Fine‑Tuning** | Domain‑specific data, instruction tuning. | LoRA, PEFT (Parameter‑Efficient Fine‑Tuning). |
# | **RLHF** (Reinforcement Learning from Human Feedback) | Reward model trained on human preferences → policy gradient. | Proximal Policy Optimization (PPO). |
# | **Evaluation** | Perplexity, BLEU, ROUGE, FID, human judgment. | OpenAI API, internal metrics. |
# | **Deployment** | Quantization, pruning, serverless inference. | ONNX, TensorRT, Triton Inference Server. |
#
# ---
#
# ### 5. Key Performance Drivers
#
# | Factor | Effect | Typical Scale |
# |--------|--------|---------------|

# %%
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(response.content)
#
# AttributeError: 'generator' object has no attribute 'content'
