# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm=ChatGroq(model="openai/gpt-oss-20b")

# %%
from langchain.agents import create_agent
from langchain_nimble import NimbleToolkit

toolkit = NimbleToolkit()

tools = toolkit.get_tools()

search_tool = next(
    tool for tool in tools
    if tool.name == "nimble_search"
)

agent = create_agent(
    model=llm,
    tools=[search_tool],
    system_prompt=(
        "You are a research assistant. "
        "Use nimble_search whenever the user asks for current information."
    ),
)

response = agent.invoke({
    "messages": [
        (
            "user",
            "What are the latest developments in AI agents? "
            "Summarize the key findings."
        )
    ]
})

print(response["messages"][-1].content)
# Out:
# I’m sorry, but I couldn’t retrieve up‑to‑date web results for 2026 (the search tool is currently restricted).
# Below is a synthesis of the most recent (2023‑2024) developments in AI agents that researchers and industry have been publishing, along with the key take‑away findings that are shaping the field.  If you need anything beyond that timeframe, let me know and I’ll do my best with the knowledge I have.
#
# | Theme | Representative Work / Product | Key Findings |
# |-------|------------------------------|--------------|
# | **Foundation‑model‑driven agents** | • OpenAI’s **GPT‑4o** and **ChatGPT‑4o** “Agent” mode <br>• Anthropic’s **Claude 3.5 Sonnet** “Agent” <br>• Meta’s **Llama 3.1** “Agent” framework | • Agents built on top of large multimodal models can plan, browse, and execute tasks with minimal fine‑tuning. <br>• End‑to‑end “self‑refinement” (e.g., ReAct, Self‑Ask, Chain‑of‑Thought) improves reasoning accuracy by 10‑20 % on complex benchmarks. |
# ...

# %%
for msg in response["messages"]:
    print("\n---", type(msg).__name__, "---")
    print("Content:", msg.content)

    if hasattr(msg, "tool_calls"):
        print("Tool calls:", msg.tool_calls)
# Out:
# --- HumanMessage ---
# Content: What are the latest developments in AI agents? Summarize the key findings.
#
# --- AIMessage ---
# Content:
# Tool calls: [{'name': 'nimble_search', 'args': {'include_answer': True, 'max_results': 10, 'query': 'latest developments in AI agents 2026', 'search_depth': 'lite'}, 'id': 'fc_f1cf7c57-427e-45a2-84cb-641f417c666b', 'type': 'tool_call'}]
#
# --- ToolMessage ---
# Content: Nimble API search failed with client error (403): Error code: 403 - {'detail': 'This feature is only available for enterprise accounts. Please contact sales for access.'}
#
# --- AIMessage ---
# Content: I’m sorry, but I couldn’t retrieve up‑to‑date web results for 2026 (the search tool is currently restricted).
# ...

# %%
response = llm.invoke("What are the latest developments in AI agents?")
print(response.content)
# Out:
# Below is a snapshot of the most significant, concrete advances in AI agents that have emerged in the last year (2025‑2026).  The field is moving fast, so the list is not exhaustive, but it captures the key trends, model releases, and tooling that are reshaping how we build, deploy, and regulate autonomous agents.
#
# | Category | Highlights | Why it matters |
# |----------|------------|----------------|
# ...
