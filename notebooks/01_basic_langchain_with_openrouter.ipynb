# %% [markdown]
# #### Load ENV Variables

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# python-dotenv could not parse statement starting at line 2
# True

# %%
import os

# %%
os.getenv("OPENROUTER_APIKEY")
