# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
document=[
    'Kohli was the captain of the 2008 U19 World Cup winning team and was a crucial member of the Indian', 'of the Indian teams that won 2011 Cricket World Cup, 2013 Champions Trophy, 2024 T20 World Cup, and', 'T20 World Cup, and 2025 Champions Trophy. He plays for Royal Challengers Bengaluru in the Indian', 'in the Indian Premier League and for Delhi in domestic cricket. In 2013, Kohli was ranked number', 'was ranked number one in the ODI batting rankings. In 2015, he achieved the same in T20I cricket.', 'in T20I cricket. In 2018, he was ranked number one in Test cricket, making him the only Indian to', 'the only Indian to hold the top spot in all three formats. He is the first player to score 20,000', 'to score 20,000 international runs in a decade. He was the Cricketer of the Decade for 2011 to', 'Decade for 2011 to 2020.'
]

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(model="gemini-embedding-2-preview")
vector = embeddings.embed_documents("document")

# %%
print(len(vector[0]))
# Out:
# 3072

# %%
from langchain_chroma import Chroma

vector_store = Chroma.from_texts(
    texts=document,
    embedding=embeddings,
    persist_directory="../databases/ChromaDB",  # Where to save data locally, remove if not necessary
)

# %%
query="Kohli"
result=vector_store.similarity_search(query=query)
result
# Out:
# [Document(id='c4858749-89e2-4f9e-9f6e-182f9ce02791', metadata={}, page_content='Kohli was the captain of the 2008 U19 World Cup winning team and was a crucial member of the Indian'),
#  Document(id='5398c927-f85c-41e9-8735-719c87664bea', metadata={}, page_content='in the Indian Premier League and for Delhi in domestic cricket. In 2013, Kohli was ranked number'),
#  Document(id='5056207f-736a-485f-820c-21ca427d279e', metadata={}, page_content='the only Indian to hold the top spot in all three formats. He is the first player to score 20,000'),
#  Document(id='8a8dcba3-6c21-48e8-aff5-a27d8c31db94', metadata={}, page_content='T20 World Cup, and 2025 Champions Trophy. He plays for Royal Challengers Bengaluru in the Indian')]

# %%
print(vector_store._collection.count())
# Out:
# 17
